# %%
import pandas as pd

df = pd.read_excel('menu_with_allergies.xlsx')
df
# Out:
#              restaurant_name  \
# 0     Starbucks (สตาร์บัคส์)
# 1     Starbucks (สตาร์บัคส์)
# 2     Starbucks (สตาร์บัคส์)
# 3     Starbucks (สตาร์บัคส์)
# 4     Starbucks (สตาร์บัคส์)
# ...                      ...
# 2868          TiTiCaCa Booth
# 2869          TiTiCaCa Booth
# 2870          TiTiCaCa Booth
# 2871          TiTiCaCa Booth
# 2872          TiTiCaCa Booth
#
#                                              menu_image  \
# 0     https://img.wongnai.com/p/128x128/2025/02/13/b...
# 1     https://img.wongnai.com/p/128x128/2025/02/13/1...
# 2     https://img.wongnai.com/p/128x128/2025/02/13/6...
# 3     https://img.wongnai.com/p/128x128/2025/02/13/a...
# 4     https://img.wongnai.com/p/128x128/2025/02/13/0...
# ...                                                 ...
# 2868  https://img.wongnai.com/p/128x128/2023/12/29/2...
# 2869  https://img.wongnai.com/p/128x128/2024/06/01/c...
# 2870  https://img.wongnai.com/p/128x128/2023/12/29/b...
# 2871  https://img.wongnai.com/p/128x128/2023/12/29/8...
# 2872  https://img.wongnai.com/p/128x128/2024/06/01/6...
#
#                                      menu_name  \
# 0                         Blossom Coconut Roll
# 1     Lychee Rose Juice Mixed with Pomegranate
# 2                            Mango Yogurt Cake
# 3               Honey Nougat Cream Frappuccino
# 4               Honey Nougat Oatmilk Macchiato
# ...                                        ...
# 2868                                 cold cuts
# 2869                                hash brown
# 2870                              Chicken pate
# 2871                                pork tacos
# 2872                            fish and chips
#
#                                          ingredients     characteristics  \
# 0             แป้งเค้ก, มะพร้าวขูด, น้ำตาล, ไข่, เนย           หวาน, มัน
# 1     ลิ้นจี่, น้ำกุหลาบ, น้ำทับทิม, น้ำตาล, น้ำแข็ง  หวาน, เปรี้ยว, มัน
# 2       มะม่วง, โยเกิร์ต, แป้งเค้ก, น้ำตาล, ไข่, เนย           หวาน, มัน
# 3            นม, น้ำผึ้ง, นูกัต, ครีม, กาแฟ, น้ำแข็ง           หวาน, มัน
# 4                   นมข้าวโอ๊ต, น้ำผึ้ง, นูกัต, กาแฟ           หวาน, มัน
# ...                                              ...                 ...
# 2868                           เนื้อสัตว์แปรรูป, ผัก     เค็ม, หอม, นุ่ม
# 2869                                        มันฝรั่ง     เค็ม, มัน, กรอบ
# 2870                               ไก่บด, เครื่องเทศ     มัน, กรอบ, เค็ม
# 2871                         หมู, แป้งตอร์ติญ่า, ผัก      เผ็ด, หอม, มัน
# 2872                ปลาทอด, มันฝรั่งทอด, ทาร์ทาร์ซอส     กรอบ, หอม, เค็ม
#
#               menu_category      matched_allergies
# 0     ของหวาน, เบเกอรี/เค้ก      นม, แป้งสาลี, ไข่
# 1      เครื่องดื่ม/น้ำผลไม้                    NaN
# 2     ของหวาน, เบเกอรี/เค้ก      นม, แป้งสาลี, ไข่
# 3      เครื่องดื่ม/น้ำผลไม้  ถั่วเปลือกแข็ง,นม, นม
# 4      เครื่องดื่ม/น้ำผลไม้      ถั่วเปลือกแข็ง,นม
# ...                     ...                    ...
# 2868          อาหารจานเดียว             ถั่วเหลือง
# 2869          อาหารจานเดียว                    NaN
# 2870          อาหารจานเดียว                    NaN
# 2871         อาหารเม็กซิกัน               แป้งสาลี
# 2872           อาหารฟิวชั่น            ปลา, ไข่,นม
#
# [2873 rows x 7 columns]

# %%
#Replace 128x128 with 400x400 in menu_image
df['menu_image'] = df['menu_image'].str.replace('128x128', '400x400')
df
# Out:
#              restaurant_name  \
# 0     Starbucks (สตาร์บัคส์)
# 1     Starbucks (สตาร์บัคส์)
# 2     Starbucks (สตาร์บัคส์)
# 3     Starbucks (สตาร์บัคส์)
# 4     Starbucks (สตาร์บัคส์)
# ...                      ...
# 2868          TiTiCaCa Booth
# 2869          TiTiCaCa Booth
# 2870          TiTiCaCa Booth
# 2871          TiTiCaCa Booth
# 2872          TiTiCaCa Booth
#
#                                              menu_image  \
# 0     https://img.wongnai.com/p/400x400/2025/02/13/b...
# 1     https://img.wongnai.com/p/400x400/2025/02/13/1...
# 2     https://img.wongnai.com/p/400x400/2025/02/13/6...
# 3     https://img.wongnai.com/p/400x400/2025/02/13/a...
# 4     https://img.wongnai.com/p/400x400/2025/02/13/0...
# ...                                                 ...
# 2868  https://img.wongnai.com/p/400x400/2023/12/29/2...
# 2869  https://img.wongnai.com/p/400x400/2024/06/01/c...
# 2870  https://img.wongnai.com/p/400x400/2023/12/29/b...
# 2871  https://img.wongnai.com/p/400x400/2023/12/29/8...
# 2872  https://img.wongnai.com/p/400x400/2024/06/01/6...
#
#                                      menu_name  \
# 0                         Blossom Coconut Roll
# 1     Lychee Rose Juice Mixed with Pomegranate
# 2                            Mango Yogurt Cake
# 3               Honey Nougat Cream Frappuccino
# 4               Honey Nougat Oatmilk Macchiato
# ...                                        ...
# 2868                                 cold cuts
# 2869                                hash brown
# 2870                              Chicken pate
# 2871                                pork tacos
# 2872                            fish and chips
#
#                                          ingredients     characteristics  \
# 0             แป้งเค้ก, มะพร้าวขูด, น้ำตาล, ไข่, เนย           หวาน, มัน
# 1     ลิ้นจี่, น้ำกุหลาบ, น้ำทับทิม, น้ำตาล, น้ำแข็ง  หวาน, เปรี้ยว, มัน
# 2       มะม่วง, โยเกิร์ต, แป้งเค้ก, น้ำตาล, ไข่, เนย           หวาน, มัน
# 3            นม, น้ำผึ้ง, นูกัต, ครีม, กาแฟ, น้ำแข็ง           หวาน, มัน
# 4                   นมข้าวโอ๊ต, น้ำผึ้ง, นูกัต, กาแฟ           หวาน, มัน
# ...                                              ...                 ...
# 2868                           เนื้อสัตว์แปรรูป, ผัก     เค็ม, หอม, นุ่ม
# 2869                                        มันฝรั่ง     เค็ม, มัน, กรอบ
# 2870                               ไก่บด, เครื่องเทศ     มัน, กรอบ, เค็ม
# 2871                         หมู, แป้งตอร์ติญ่า, ผัก      เผ็ด, หอม, มัน
# 2872                ปลาทอด, มันฝรั่งทอด, ทาร์ทาร์ซอส     กรอบ, หอม, เค็ม
#
#               menu_category      matched_allergies
# 0     ของหวาน, เบเกอรี/เค้ก      นม, แป้งสาลี, ไข่
# 1      เครื่องดื่ม/น้ำผลไม้                    NaN
# 2     ของหวาน, เบเกอรี/เค้ก      นม, แป้งสาลี, ไข่
# 3      เครื่องดื่ม/น้ำผลไม้  ถั่วเปลือกแข็ง,นม, นม
# 4      เครื่องดื่ม/น้ำผลไม้      ถั่วเปลือกแข็ง,นม
# ...                     ...                    ...
# 2868          อาหารจานเดียว             ถั่วเหลือง
# 2869          อาหารจานเดียว                    NaN
# 2870          อาหารจานเดียว                    NaN
# 2871         อาหารเม็กซิกัน               แป้งสาลี
# 2872           อาหารฟิวชั่น            ปลา, ไข่,นม
#
# [2873 rows x 7 columns]

# %%
df.to_excel('menu_with_allergies.xlsx', index=False)
